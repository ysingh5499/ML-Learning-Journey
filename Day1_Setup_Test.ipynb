# %%
print("Hello World")
# Out:
# Hello World

# %%
print("First Commit")
# Out:
# First Commit

# %%
import numpy as np
import pandas

# %%
v1 = np.array([1,2,3])
v2 = np.array([4,5,6])

v3 = v1+v2 
print (v3)
# Out:
# [5 7 9]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a figure with subplots for different visualization methods
fig = plt.figure(figsize=(15, 10))

# Example vectors
v1 = np.array([2, 3, 1])  # 3D vector
v2 = np.array([1, 2])     # 2D vector

# 1. 2D Vector as an arrow
ax1 = fig.add_subplot(221)
ax1.quiver(0, 0, v2[0], v2[1], angles='xy', scale_units='xy', scale=1, color='r', label='v2 = [1, 2]')
ax1.set_xlim([-0.5, 3])
ax1.set_ylim([-0.5, 3])
ax1.grid(True)
ax1.set_title('2D Vector as Arrow')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.legend()
ax1.axhline(y=0, color='k', linestyle='-', alpha=0.3)
ax1.axvline(x=0, color='k', linestyle='-', alpha=0.3)

# 2. Multiple 2D vectors
ax2 = fig.add_subplot(222)
v3 = np.array([3, 1])
ax2.quiver(0, 0, v2[0], v2[1], angles='xy', scale_units='xy', scale=1, color='r', label='v2 = [1, 2]')
ax2.quiver(0, 0, v3[0], v3[1], angles='xy', scale_units='xy', scale=1, color='b', label='v3 = [3, 1]')
# Vector addition
ax2.quiver(0, 0, v2[0] + v3[0], v2[1] + v3[1], angles='xy', scale_units='xy', scale=1, color='g', label='v2 + v3')
ax2.quiver(v2[0], v2[1], v3[0], v3[1], angles='xy', scale_units='xy', scale=1, color='g', alpha=0.3)
ax2.set_xlim([-0.5, 5])
ax2.set_ylim([-0.5, 4])
ax2.grid(True)
ax2.set_title('Multiple 2D Vectors and Addition')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.legend()
ax2.axhline(y=0, color='k', linestyle='-', alpha=0.3)
ax2.axvline(x=0, color='k', linestyle='-', alpha=0.3)

# 3. 3D Vector
ax3 = fig.add_subplot(223, projection='3d')
ax3.quiver(0, 0, 0, v1[0], v1[1], v1[2], color='r', label='v1 = [2, 3, 1]')
ax3.set_xlim([0, 3])
ax3.set_ylim([0, 4])
ax3.set_zlim([0, 2])
ax3.set_title('3D Vector')
ax3.set_xlabel('X')
ax3.set_ylabel('Y')
ax3.set_zlabel('Z')
ax3.legend()

# 4. Multiple 3D vectors
ax4 = fig.add_subplot(224, projection='3d')
v4 = np.array([1, 1, 2])
ax4.quiver(0, 0, 0, v1[0], v1[1], v1[2], color='r', label='v1 = [2, 3, 1]')
ax4.quiver(0, 0, 0, v4[0], v4[1], v4[2], color='b', label='v4 = [1, 1, 2]')
# Cross product
cross_product = np.cross(v1, v4)
ax4.quiver(0, 0, 0, cross_product[0], cross_product[1], cross_product[2], 
           color='g', label=f'v1 × v4 = {cross_product}')
ax4.set_xlim([0, 3])
ax4.set_ylim([0, 4])
ax4.set_zlim([0, 3])
ax4.set_title('Multiple 3D Vectors and Cross Product')
ax4.set_xlabel('X')
ax4.set_ylabel('Y')
ax4.set_zlabel('Z')
ax4.legend()

plt.tight_layout()
plt.show()
